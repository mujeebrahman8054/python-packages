# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#statistica data
#replot used for creating relational plots 
a=sns.load_dataset('flights')
a.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
sns.relplot(x="passengers",y="month",data=a)

# %%
a=sns.load_dataset('flights')
sns.relplot(x="passengers",y="month",hue="year",data=a)

# %%
b=sns.load_dataset("tips")
sns.relplot(x="time",y="tip",data=b,kind="line")

# %%
#categorical data
#catplot used for creating catogorical plot
sns.catplot(x="day",y="total_bill",data=b)

# %%
sns.catplot(x="day",y="total_bill",kind="violin",data=b)

# %%
sns.catplot(x="day",y="total_bill",kind="boxen",data=b)

# %%
#distribution
from scipy import stats

# %%
#displot used for creating distributions plots 
#univarient
c=np.random.normal(loc=5,size=100,scale=2)
sns.displot(c)

# %%
a=sns.load_dataset("iris")
b=sns.FacetGrid(a,col="species")
b.map(plt.hist,"sepal_length")

# %%
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style="darkgrid")
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style="dark")
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style="white",color_codes=True)
a=sns.load_dataset("tips")
sns.boxplot(x="day",y="total_bill",data=a)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set(style="white",color_codes=True)
a=sns.load_dataset("tips")
sns.boxplot(x="day",y="total_bill",data=a)
sns.despine(offset=10,trim=True)

# %%
#color pellette
c=sns.color_palette()
sns.palplot(c)

# %%
a=sns.load_dataset("tips")
a.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#example

# %%
#load a built in dataset based on US state car crash percentages
crash_df=sns.load_dataset("car_crashes")

# %%
#distribution plot
#provides a wayt to look at a univariete distribution
#a univriate distribution provides a distribution for one variable
sns.distplot(crash_df["not_distracted"],kde=False ,bins=25)
# Out:
# C:\Users\MUJEEB\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted'>

# %%
#joint plot
#jointplot compares 2 distributions and plots a scatter plot by default
#a sw can see as people tend to speed they alse tend to drink & drive
sns.jointplot(x="speeding",y="alcohol",data=crash_df,kind="reg")

# %%
#kde plot
sns.kdeplot(crash_df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
#pair plot
sns.pairplot(crash_df)
tips_df=sns.load_dataset('tips')

# %%
#rug plots
sns.rugplot(tips_df['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
#styling
sns.set_style('white')
plt.figure(figsize=(8,4))
sns.set_context('paper',font_scale=1.4)
sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='reg')
sns.despine(left=False,bottom=False)

# %%
#catogorical plots
#bar plots
sns.barplot(x='sex',y='total_bill',data=tips_df,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
#count plot
sns.countplot(x='sex',data=tips_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#box plot
plt.figure(figsize=(14,9))
sns.set_style('darkgrid')
sns.boxplot(x='day',y='total_bill',data=tips_df,hue="sex")
plt.legend(loc=0)

# %%
#violin plot
#combination of boxplot and kde
sns.violinplot(x='day',y='total_bill',data=tips_df,hue='sex',split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#strip plot
plt.figure(figsize=(8,5))
sns.stripplot(x='day',y='total_bill',data=tips_df,jitter=True,hue='sex',dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#swarm plot
sns.violinplot(x='day',y='total_bill',data=tips_df)
sns.swarmplot(x='day',y='total_bill',data=tips_df,color='white')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#palettes
plt.figure(figsize=(8,6))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='day',y='total_bill',data=tips_df,hue='sex',palette='seismic')
plt.legend(loc=0)

# %%
#facet grid
att_df=sns.load_dataset('attention')
att_fg=sns.FacetGrid(att_df,col='subject',col_wrap=5,height=1.5)
att_fg.map(plt.plot,'solutions','score',marker='.')
