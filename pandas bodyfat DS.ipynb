# %%
import pandas as pd
import numpy as np

# %%
bf=pd.read_csv("C:/Users/MUJEEB/Downloads/bodyfat.csv")
print(bf)
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
bf1=bf.head(10)
bf1
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 8   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 9   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# ...

# %%
bf1.describe()
# Out:
#          Density   BodyFat        Age      Weight     Height       Neck  \
# count  10.000000  10.00000  10.000000   10.000000  10.000000  10.000000
# mean    1.064430  15.11000  24.000000  180.700000  71.425000  37.390000
# std     0.018528   8.09821   1.490712   17.658725   2.741274   2.345421
# min     1.034000   4.10000  22.000000  154.000000  66.250000  34.000000
# 25%     1.051375  10.72500  23.000000  173.937500  70.125000  36.250000
# 50%     1.070600  12.35000  24.000000  182.625000  72.250000  37.600000
# 75%     1.074375  20.47500  25.000000  189.437500  73.250000  38.400000
# max     1.090000  28.70000  26.000000  210.250000  74.750000  42.100000
#
#             Chest     Abdomen         Hip      Thigh       Knee      Ankle  \
# count   10.000000   10.000000   10.000000  10.000000  10.000000  10.000000
# mean    99.130000   88.720000  100.470000  61.100000  39.270000  23.660000
# std      4.170811    5.305511    3.675459   2.529383   1.989444   1.080329
# ...

# %%
bf1.sort_index(axis=0,ascending=False)
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 9   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
# 8   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 9  41.7   25.0    35.6     30.0   19.2
# 8  38.3   23.8    35.9     31.1   18.2
# ...

# %%
bf1.sort_values(by="BodyFat")
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 8   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 9   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 8  38.3   23.8    35.9     31.1   18.2
# 1  37.3   23.4    30.5     28.9   18.2
# ...

# %%
bf1["Age"]
# Out:
# 0    23
# 1    22
# 2    22
# 3    26
# 4    24
# 5    24
# 6    26
# 7    25
# 8    25
# 9    23
# Name: Age, dtype: int64

# %%
bf1[5:8]
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 5  42.0   25.6    35.7     30.6   18.8
# 6  38.3   22.9    31.9     27.8   17.7
# 7  39.4   23.2    30.5     29.0   18.8

# %%
bf1.loc[:,["Neck","Chest"]]
# Out:
#    Neck  Chest
# 0  36.2   93.1
# 1  38.5   93.6
# 2  34.0   95.8
# 3  37.4  101.8
# 4  34.4   97.3
# 5  39.0  104.5
# 6  36.4  105.1
# 7  37.8   99.6
# 8  38.1  100.9
# 9  42.1   99.6

# %%
bf1[bf1["Weight"]>150]
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 8   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 9   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# ...

# %%
ds1=[bf1[:5],bf1[5:10]]
print(ds1)
# Out:
# [   Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7  ,    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# ...

# %%
pd.concat(ds1)
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 8   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 9   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# ...

# %%
bf1.groupby(["Weight",'Height']).sum()
# Out:
#                Density  BodyFat  Age  Neck  Chest  Abdomen    Hip  Thigh  \
# Weight Height
# 154.00 66.25    1.0414     25.3   22  34.0   95.8     87.9   99.2   59.6
# 154.25 67.75    1.0708     12.3   23  36.2   93.1     85.2   94.5   59.0
# 173.25 72.25    1.0853      6.1   22  38.5   93.6     83.0   98.7   58.7
# 176.00 72.50    1.0704     12.4   25  37.8   99.6     88.5   97.1   60.0
# 181.00 69.75    1.0549     19.2   26  36.4  105.1     90.7  100.3   58.4
# 184.25 71.25    1.0340     28.7   24  34.4   97.3    100.0  101.9   63.2
# 184.75 72.25    1.0751     10.4   26  37.4  101.8     86.4  101.2   60.1
# 191.00 74.00    1.0900      4.1   25  38.1  100.9     82.5   99.9   62.9
# 198.25 73.50    1.0722     11.7   23  42.1   99.6     88.6  104.1   63.1
# 210.25 74.75    1.0502     20.9   24  39.0  104.5     94.4  107.8   66.0
#
#                Knee  Ankle  Biceps  Forearm  Wrist
# Weight Height
# 154.00 66.25   38.9   24.0    28.8     25.2   16.6
# ...

# %%
bf1["weight per height"]=bf1["Weight"]-100
print(bf1)
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 8   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 9   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
#
#    Knee  Ankle  Biceps  Forearm  Wrist  weight loss  weight per height
# ...

# %%
newind="A B C D E F G H I J".split()
bf1["states"]=newind
bf1
# Out:
# C:\Users\MUJEEB\AppData\Local\Temp\ipykernel_16180\1131802634.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bf1["states"]=newind
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# ...

# %%
bf1.set_index("states",inplace=True)
bf1
# Out:
#         Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# states
# A        1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# B        1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# C        1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# D        1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# E        1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# F        1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8
# G        1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3
# H        1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1
# I        1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9
# J        1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1
#
#         Thigh  Knee  Ankle  Biceps  Forearm  Wrist  weight loss  \
# states
# ...

# %%
outside=["G1","G1","G1","G2","G2","G2","G3","G3","G3","G4"]
inside=[1,2,3,1,2,3,1,2,3,1]
hier_index=list(zip(outside,inside))
hier_index=pd.MultiIndex.from_tuples(hier_index)
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3),
#             ('G3', 1),
#             ('G3', 2),
#             ('G3', 3),
#             ('G4', 1)],
#            )

# %%
dg=bf1.set_index(hier_index)
print(dg)
# Out:
#       Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# G1 1   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
#    2   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
#    3   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# G2 1   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
#    2   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
#    3   1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8
# G3 1   1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3
#    2   1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1
#    3   1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9
# G4 1   1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1
#
#       Thigh  Knee  Ankle  Biceps  Forearm  Wrist  weight loss  \
# G1 1   59.0  37.3   21.9    32.0     27.4   17.1        54.25
# ...

# %%
dg.xs(["G1",2])
# Out:
# C:\Users\MUJEEB\AppData\Local\Temp\ipykernel_16180\3445519903.py:1: FutureWarning: Passing lists as key for xs is deprecated and will be removed in a future version. Pass key as a tuple instead.
#   dg.xs(["G1",2])
# Density                1.0853
# BodyFat                6.1000
# Age                   22.0000
# Weight               173.2500
# Height                72.2500
# Neck                  38.5000
# Chest                 93.6000
# Abdomen               83.0000
# Hip                   98.7000
# Thigh                 58.7000
# Knee                  37.3000
# Ankle                 23.4000
# Biceps                30.5000
# Forearm               28.9000
# Wrist                 18.2000
# weight loss           73.2500
# weight per height     73.2500
# Name: (G1, 2), dtype: float64

# %%
dg.index.names=["Group","Num"]
dg
# Out:
#            Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# Group Num
# G1    1     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
#       2     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
#       3     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# G2    1     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
#       2     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
#       3     1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8
# G3    1     1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3
#       2     1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1
#       3     1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9
# G4    1     1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1
#
#            Thigh  Knee  Ankle  Biceps  Forearm  Wrist  weight loss  \
# Group Num
# ...

# %%
dg.xs("G1")
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen   Hip  Thigh  \
# Num
# 1     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2  94.5   59.0
# 2     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0  98.7   58.7
# 3     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9  99.2   59.6
#
#      Knee  Ankle  Biceps  Forearm  Wrist  weight loss  weight per height
# Num
# 1    37.3   21.9    32.0     27.4   17.1        54.25              54.25
# 2    37.3   23.4    30.5     28.9   18.2        73.25              73.25
# 3    38.9   24.0    28.8     25.2   16.6        54.00              54.00
